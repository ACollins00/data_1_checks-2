# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = [7.50, 3.5]
plt.rcParams["figure.autolayout"] = True

columns = ["Sunrise", "Month"]

df = pd.read_csv("assets\CincinnatiSunrise.csv - Copy.csv")

print("Contents in csv file:", df)

plt.plot(df.Sunrise, df.Month)

plt.show()
# Out:
# Contents in csv file:         Month Sunrise
# 0     January    7:57
# 1     Febuary    7:44
# 2       March    7:10
# 3       April    7:22
# 4         May    6:39
# 5        June    6:14
# 6        July    6:15
# 7      August    6:38
# 8   September    7:06
# 9     October    7:34
# 10   November    8:05
# 11   December    7:38
# C:\Users\Amy\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:151: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)
